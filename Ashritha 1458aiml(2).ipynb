# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Delivery_person_Ratings', bins=10, kde=True)
plt.title('Distribution of Delivery Person Ratings')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual variable name of your DataFrame
data = pd.read_csv('/content/deliverytime.csv')  # Load your data into a DataFrame

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Type_of_order')
plt.title('Order Type Distribution')
plt.xlabel('Order Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual variable name of your DataFrame
data = pd.read_csv('/content/deliverytime.csv')  # Load your data into a DataFrame

plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Type_of_order')
plt.title('Order Type Distribution')
plt.xlabel('Order Type')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
# Replace 'data' with the actual variable name of your DataFrame
data = pd.read_csv('/content/deliverytime.csv')  # Load your data into a DataFrame

plt.figure(figsize=(12, 8))
sns.boxplot(data=data, x='Type_of_order', y='Time_taken(min)')
plt.title('Time Taken Distribution by Order Type')
plt.xlabel('Order Type')
plt.ylabel('Time Taken (min)')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame
data = pd.read_csv('/content/deliverytime.csv')  # Load your data into a DataFrame

plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Delivery_person_Age', bins=10, kde=True)
plt.title('Distribution of Delivery Person Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Delivery_person_Age', y='Time_taken(min)', data=data)
plt.title('Delivery Person Age vs. Time Taken')
plt.xlabel('Delivery Person Age')
plt.ylabel('Time Taken (min)')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load your data into a DataFrame
data = pd.read_csv('/content/deliverytime.csv')

# Selecting features and target variable
features = data[['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude']]
target = data['Time_taken(min)']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Creating the decision tree regressor model
regressor = DecisionTreeRegressor(random_state=42)

# Fitting the model
regressor.fit(X_train, y_train)

# Making predictions
predictions = regressor.predict(X_test)

# Calculating the mean squared error
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')

# Calculate RMSE
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

# Calculate MAE
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')

# Calculate MAPE
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
print(f'Mean Absolute Percentage Error: {mape}%')

# Calculate Mean Squared Error Percentage
mse_percentage = np.mean(((y_test - predictions) / y_test)**2) * 100
print(f'Mean Squared Error Percentage: {mse_percentage}%')

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print(f'R-squared: {r2}')

# Plotting actual vs predicted values
plt.figure(figsize=(3, 3))
plt.scatter(y_test, predictions, color='b', label='Predicted', alpha=0.5)
plt.scatter(y_test, y_test, color='y', label='Actual', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
plt.xlabel('Actual Time Taken (min)')
plt.ylabel('Predicted Time Taken (min)')
plt.title('Actual vs Predicted Time Taken')
plt.legend()
plt.grid(True)
plt.show()

# You can also export the tree visualization if needed
# from sklearn.tree import export_graphviz
# export_graphviz(regressor, out_file='tree.dot', feature_names=features.columns)
# Out:
# Mean Squared Error: 112.97061992244365
# Root Mean Squared Error: 10.628763800294164
# Mean Absolute Error: 8.190594889629873
# Mean Absolute Percentage Error: 35.49088954039949%
# Mean Squared Error Percentage: 25.502038006297084%
# R-squared: -0.28846967028825277

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load your data into a DataFrame
data = pd.read_csv('/content/deliverytime.csv')

# Selecting features and target variable
features = data[['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude']]
target = data['Time_taken(min)']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Creating the SVR model
regressor = SVR(kernel='rbf', C=1.0, epsilon=0.2)

# Fitting the model
regressor.fit(X_train, y_train)

# Making predictions
predictions = regressor.predict(X_test)

# Calculating the mean squared error
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')

# Calculate RMSE
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

# Calculate MAE
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')

# Calculate MAPE
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
print(f'Mean Absolute Percentage Error: {mape}%')

# Calculate Mean Squared Error Percentage
mse_percentage = np.mean(((y_test - predictions) / y_test)**2) * 100
print(f'Mean Squared Error Percentage: {mse_percentage}%')

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print(f'R-squared: {r2}')

# Plotting actual vs predicted values
plt.figure(figsize=(3, 3))
plt.scatter(y_test, predictions, color='b', label='Predicted', alpha=0.5)
plt.scatter(y_test, y_test, color='y', label='Actual', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
plt.xlabel('Actual Time Taken (min)')
plt.ylabel('Predicted Time Taken (min)')
plt.title('Actual vs Predicted Time Taken')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 79.08275311795882
# Root Mean Squared Error: 8.89284842544608
# Mean Absolute Error: 7.0415932250475155
# Mean Absolute Percentage Error: 30.315824902577305%
# Mean Squared Error Percentage: 16.76482374792379%
# R-squared: 0.09803337447084082

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load your data into a DataFrame
data = pd.read_csv('/content/deliverytime.csv')

# Selecting features and target variable
features = data[['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude']]
target = data['Time_taken(min)']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Creating the KNN regressor model
regressor = KNeighborsRegressor(n_neighbors=5)

# Fitting the model
regressor.fit(X_train, y_train)

# Making predictions
predictions = regressor.predict(X_test)

# Calculating the mean squared error
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')

# Calculate RMSE
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

# Calculate MAE
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')

# Calculate MAPE
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
print(f'Mean Absolute Percentage Error: {mape}%')

# Calculate Mean Squared Error Percentage
mse_percentage = np.mean(((y_test - predictions) / y_test)**2) * 100
print(f'Mean Squared Error Percentage: {mse_percentage}%')

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print(f'R-squared: {r2}')

# Plotting actual vs predicted values
plt.figure(figsize=(3, 3))
plt.scatter(y_test, predictions, color='b', label='Predicted', alpha=0.5)
plt.scatter(y_test, y_test, color='y', label='Actual', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
plt.xlabel('Actual Time Taken (min)')
plt.ylabel('Predicted Time Taken (min)')
plt.title('Actual vs Predicted Time Taken')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 72.41551924553131
# Root Mean Squared Error: 8.509730856233428
# Mean Absolute Error: 6.6718719157802395
# Mean Absolute Percentage Error: 29.124021001234496%
# Mean Squared Error Percentage: 16.232421739115033%
# R-squared: 0.1740755227323878

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load your data into a DataFrame
data = pd.read_csv('/content/deliverytime.csv')

# Selecting features and target variable
features = data[['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude']]
target = data['Time_taken(min)']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Creating the Random Forest regressor model
regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Fitting the model
regressor.fit(X_train, y_train)

# Making predictions
predictions = regressor.predict(X_test)

# Calculating the mean squared error
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')

# Calculate RMSE
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

# Calculate MAE
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')

# Calculate MAPE
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
print(f'Mean Absolute Percentage Error: {mape}%')

# Calculate Mean Squared Error Percentage
mse_percentage = np.mean(((y_test - predictions) / y_test)**2) * 100
print(f'Mean Squared Error Percentage: {mse_percentage}%')

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print(f'R-squared: {r2}')

# Plotting actual vs predicted values
plt.figure(figsize=(3, 3))
plt.scatter(y_test, predictions, color='b', label='Predicted', alpha=0.5)
plt.scatter(y_test, y_test, color='y', label='Actual', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
plt.xlabel('Actual Time Taken (min)')
plt.ylabel('Predicted Time Taken (min)')
plt.title('Actual vs Predicted Time Taken')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 66.61331620403976
# Root Mean Squared Error: 8.161698120124253
# Mean Absolute Error: 6.3912463413891265
# Mean Absolute Percentage Error: 28.320135970055393%
# Mean Squared Error Percentage: 15.619034496002937%
# R-squared: 0.24025168999559743

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# Load your data into a DataFrame
data = pd.read_csv('/content/deliverytime.csv')

# Selecting features and target variable
features = data[['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude']]
target = data['Time_taken(min)']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Scaling the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Creating the MLP regressor model
regressor = MLPRegressor(hidden_layer_sizes=(100,), activation='relu', solver='adam', max_iter=500, random_state=42)

# Fitting the model
regressor.fit(X_train_scaled, y_train)

# Making predictions
predictions = regressor.predict(X_test_scaled)

# Calculating the mean squared error
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')

# Calculate RMSE
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')

# Calculate MAE
mae = mean_absolute_error(y_test, predictions)
print(f'Mean Absolute Error: {mae}')

# Calculate MAPE
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100
print(f'Mean Absolute Percentage Error: {mape}%')

# Calculate Mean Squared Error Percentage
mse_percentage = np.mean(((y_test - predictions) / y_test)**2) * 100
print(f'Mean Squared Error Percentage: {mse_percentage}%')

# Calculate R-squared
r2 = r2_score(y_test, predictions)
print(f'R-squared: {r2}')

# Plotting actual vs predicted values
plt.figure(figsize=(3, 3))
plt.scatter(y_test, predictions, color='b', label='Predicted', alpha=0.5)
plt.scatter(y_test, y_test, color='y', label='Actual', alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=1)
plt.xlabel('Actual Time Taken (min)')
plt.ylabel('Predicted Time Taken (min)')
plt.title('Actual vs Predicted Time Taken')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Mean Squared Error: 65.42217234724714
# Root Mean Squared Error: 8.088397390537086
# Mean Absolute Error: 6.272602445716964
# Mean Absolute Percentage Error: 27.979699827151418%
# Mean Squared Error Percentage: 15.072661688217911%
# R-squared: 0.2538371048006246
